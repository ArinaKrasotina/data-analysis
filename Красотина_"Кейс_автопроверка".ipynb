# %% [markdown]
# <a href="https://colab.research.google.com/github/ArinaKrasotina/data-analysis/blob/main/%D0%9A%D1%80%D0%B0%D1%81%D0%BE%D1%82%D0%B8%D0%BD%D0%B0_%22%D0%9A%D0%B5%D0%B9%D1%81_%D0%B0%D0%B2%D1%82%D0%BE%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B0%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1 кейс**
#
# **Система автопроверки**

# %% [markdown]
# **Важно**
#
# Перед началом решения выполните следующую ячейку, чтобы загрузить два файла - эталонный код и код пользователя.

# %%
# !wget https://gist.github.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py

# !wget https://gist.github.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py

# !wget https://gist.github.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Out:
# --2025-12-10 10:14:59--  https://gist.github.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py [following]
# --2025-12-10 10:14:59--  https://gist.githubusercontent.com/Vs8th/aafed81d81678c807a3ad3dbf93588b2/raw/user.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106 [text/plain]
# Saving to: ‘user.py’
#
# user.py             100%[===================>]     106  --.-KB/s    in 0s
#
# 2025-12-10 10:15:00 (906 KB/s) - ‘user.py’ saved [106/106]
#
# --2025-12-10 10:15:00--  https://gist.github.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py [following]
# --2025-12-10 10:15:00--  https://gist.githubusercontent.com/Vs8th/95f7897019a4213c76e5b65234d31e30/raw/etalon.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31 [text/plain]
# Saving to: ‘etalon.py’
#
# etalon.py           100%[===================>]      31  --.-KB/s    in 0s
#
# 2025-12-10 10:15:00 (1.42 MB/s) - ‘etalon.py’ saved [31/31]
#
# --2025-12-10 10:15:00--  https://gist.github.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt [following]
# --2025-12-10 10:15:00--  https://gist.githubusercontent.com/Vs8th/59f797dfbd33f9a4be1e5ed43bb42f4d/raw/res_cor.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 355 [text/plain]
# Saving to: ‘res_cor.txt’
#
# res_cor.txt         100%[===================>]     355  --.-KB/s    in 0s
#
# 2025-12-10 10:15:01 (8.88 MB/s) - ‘res_cor.txt’ saved [355/355]

# %% [markdown]
# Давайте сразу посмотрим с каким кодом мы имеем дело.

# %%
with open('etalon.py', 'r') as f:
    lines = f.readlines()

lines
# Out:
# ['def add(a, b):\n', '    return a + b']

# %%
with open('user.py', 'r') as f:
    lines2 = f.readlines()

lines2
# Out:
# ['def add_numbers(a, b):\n',
#  '    return a - b  # Ошибка: нужно сложить, а не вычесть']

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Задача не из легких, поэтому начнем по шагам. Для начала напишите функцию `run_tests`, которая прочтет эталонный код и код пользователя из `.py` файлов, выполнит их и сохранит результаты в файл `output.txt`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import importlib

def run_tests(standard_module, user_module, test_cases, output_file):
    # Определение функций
    std_func = None
    user_func = None

    # Находим первую функцию в эталоне
    for attr in dir(standard_module):
        if not attr.startswith("_") and callable(getattr(standard_module, attr)):
            std_func = getattr(standard_module, attr)
            break

    # Находим первую функцию в user.py
    for attr in dir(user_module):
        if not attr.startswith("_") and callable(getattr(user_module, attr)):
            user_func = getattr(user_module, attr)
            break

    # Тестирование
    with open(output_file, "w") as f:
        for a, b in test_cases:
            expected = std_func(a, b)
            try:
                user_result = user_func(a, b)
            except Exception as e:
                f.write(f"Ошибка при выполнении кода пользователя: {e}")
                return

            if expected == user_result:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write(f"Ожидаемый результат: {expected}\n")
                f.write(f"Результат пользователя: {user_result}\n")

# Загрузка модулей
standard_module = importlib.import_module('etalon')
user_module = importlib.import_module('user')

test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = 'output.txt'

run_tests(standard_module, user_module, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
with open('output.txt', 'r') as file1:
    res1 = file1.read()

with open('res_cor.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1 == res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Теперь давайте двигаться дальше. Нужно добавить проверку на вредоносный код. Напишите отдельную функцию - `check_for_malicious_code`, которую мы будем вызывать перед проверкой кода.

# %% [markdown]
# Перед написанием кода, выполните следующую ячейку, в ней скачивается новый код пользователя, который проверит работу функции `check_for_malicious_code`.

# %%
# !wget https://gist.github.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Out:
# --2025-12-10 10:18:04--  https://gist.github.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Resolving gist.github.com (gist.github.com)... 140.82.114.4
# Connecting to gist.github.com (gist.github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py [following]
# --2025-12-10 10:18:04--  https://gist.githubusercontent.com/Vs8th/9f6a2c73c755cfcc088c7835ec4fb2c0/raw/user_malicious.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117 [text/plain]
# Saving to: ‘user_malicious.py’
#
# user_malicious.py   100%[===================>]     117  --.-KB/s    in 0s
#
# 2025-12-10 10:18:04 (1.66 MB/s) - ‘user_malicious.py’ saved [117/117]

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import importlib
import inspect
import ast

FORBIDDEN_NAMES = ['eval', 'exec']

def check_for_malicious_code(code, output_file):
    try:
        tree = ast.parse(code)
    except SyntaxError as e:
        return f"Код содержит синтаксическую ошибку: {e}"

    try:
        for node in ast.walk(tree):
            # Проверка атрибутов
            if isinstance(node, ast.Attribute):
                if node.attr in FORBIDDEN_NAMES:
                    return f"Код содержит запрещенный атрибут: {node.attr}"

            # Проверка вызовов eval()
            if isinstance(node, ast.Call):
                if isinstance(node.func, ast.Name) and node.func.id == "eval":
                    return "Код содержит вызов eval()"
    except Exception as e:
        return f"Код содержит вредоносные элементы: {e}"

    return None


def run_tests(standard_code, user_code, test_cases, output_file):
    with open(output_file, 'w') as f:
        for a, b in test_cases:
            try:
                expected = standard_code.add(a, b)
                result = user_code.add_numbers(a, b)
            except Exception as e:
                f.write(f"Ошибка при выполнении кода пользователя: {e}")
                return

            if expected == result:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write(f"Ожидаемый результат: {expected}\n")
                f.write(f"Результат пользователя: {result}\n")
                return


# Чтение кодов из файлов
standard_module = importlib.import_module("etalon")
user_module = importlib.import_module("user_malicious")

test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = 'output2.txt'

malicious_code_message = check_for_malicious_code(inspect.getsource(user_module), output_file)

if malicious_code_message:
    with open(output_file, 'w') as f:
        f.write("Ошибка при проверке модуля user_malicious:\n")
        f.write(malicious_code_message)
else:
    run_tests(standard_module, user_module, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
# Здесь будет скачиваться файл с эталонным ответом

# !wget https://gist.github.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Out:
# --2025-12-10 10:19:06--  https://gist.github.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Resolving gist.github.com (gist.github.com)... 140.82.114.4
# Connecting to gist.github.com (gist.github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt [following]
# --2025-12-10 10:19:06--  https://gist.githubusercontent.com/Vs8th/5197125c5ef1e1b34b7d73adccdaf4bb/raw/cor_output_2.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107 [text/plain]
# Saving to: ‘cor_output_2.txt’
#
# cor_output_2.txt    100%[===================>]     107  --.-KB/s    in 0s
#
# 2025-12-10 10:19:06 (1.81 MB/s) - ‘cor_output_2.txt’ saved [107/107]

# %%
with open('output2.txt', 'r') as file1:
    res1 = file1.read()

with open('cor_output_2.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1== res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Движемся дальше - последнее, что нам нужно проверить - время выполнения. Если время выполнения превышает 5 секунд, уведомите об этом пользователя и остановите выполнение проверки.

# %% [markdown]
# Перед написанием кода, выполните следующую ячейку, в ней скачивается новый код пользователя, который проверит работу проверки на время выполнения.

# %%
# !wget https://gist.github.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Out:
# --2025-12-10 10:30:30--  https://gist.github.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py [following]
# --2025-12-10 10:30:31--  https://gist.githubusercontent.com/Vs8th/4aba49489a8b0843ef85c4a1a93f923d/raw/user_inf.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘user_inf.py’
#
# user_inf.py         100%[===================>]      55  --.-KB/s    in 0s
#
# 2025-12-10 10:30:31 (643 KB/s) - ‘user_inf.py’ saved [55/55]

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import importlib
import multiprocessing

def run_tests(std_mod, user_mod, test_cases, output_file):
    std_func = [f for f in dir(std_mod) if callable(getattr(std_mod, f)) and not f.startswith("__")][0]
    user_func = [f for f in dir(user_mod) if callable(getattr(user_mod, f)) and not f.startswith("__")][0]
    std_func = getattr(std_mod, std_func)
    user_func = getattr(user_mod, user_func)

    with open(output_file, "w") as f:
        for args in test_cases:
            args = args if isinstance(args, (tuple,list)) else (args,)

            # таймаут через multiprocessing
            result_container = multiprocessing.Queue()
            def wrapper():
                try:
                    result_container.put(("ok", user_func(*args)))
                except Exception as e:
                    result_container.put(("error", e))

            p = multiprocessing.Process(target=wrapper)
            p.start()
            p.join(5)
            if p.is_alive():
                p.terminate()
                f.write("Предупреждение: время выполнения превышает 5 секунд.")
                return

            status, result = result_container.get()
            expected = std_func(*args)

            if status == "error":
                f.write(f"Ошибка при выполнении кода пользователя: {result}\n")
                return

            if result == expected:
                f.write("Тест пройден\n")
            else:
                f.write("Тест не пройден\n")
                f.write(f"Ожидаемый результат: {expected}\n")
                f.write(f"Результат пользователя: {result}\n")
                return


# Загрузка модулей
standard_module = importlib.import_module("etalon")
user_module = importlib.import_module("user_inf")
test_cases = [(1, 2), (3, 4), (5, 6)]
output_file = "output3.txt"

run_tests(standard_module, user_module, test_cases, output_file)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
# Здесь будет скачиваться файл с эталонным ответом

# !wget https://gist.github.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Out:
# --2025-12-10 10:31:18--  https://gist.github.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt [following]
# --2025-12-10 10:31:18--  https://gist.githubusercontent.com/Vs8th/cfcafbd2cd46e8905555b02eae78406e/raw/cor_res_3.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96 [text/plain]
# Saving to: ‘cor_res_3.txt’
#
# cor_res_3.txt       100%[===================>]      96  --.-KB/s    in 0s
#
# 2025-12-10 10:31:18 (2.00 MB/s) - ‘cor_res_3.txt’ saved [96/96]

# %%
with open('output3.txt', 'r') as file1:
    res1 = file1.read()

with open('cor_res_3.txt', 'r') as file2:
    res2 = file2.read()

try:
    assert res1 == res2
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
